# %%
from optimadewidget.optimade_widget import OptimadeQuerierWidget

w = OptimadeQuerierWidget()

w.custom_url = "https://optimade.dev.materialscloud.org/main/mc3d-pbesol-v2"
w
# Out:
# OptimadeQuerierWidget()
